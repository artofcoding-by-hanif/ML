# %% [markdown]
# Mean Squared Error (MSE) or Cost Function
# Gradient Decent -> Is an algorithm that finds best fit line for given traininf
# Global minimum
#
# y_predicted = mX + b
# MSE = 1/n SUM (y_input - y_predicted)2
#
# Derivative
# Partial Derivative - Gives the slope
# Learning rate - constant

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
def gradient_descent(x,y):
    m_curr = b_curr = 0
    rate = 0.01
    n = len(x)
    plt.scatter(x,y)
    for i in range(1000):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        print (m_curr,b_curr, cost, i)
        plt.plot(x,y_predicted,color='green')
        md = -(2/n)*sum(x*(y-y_predicted)) # M derivative
        yd = -(2/n)*sum(y-y_predicted) # Y derivative
        m_curr = m_curr - rate * md
        b_curr = b_curr - rate * yd

# %%
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

# %%
gradient_descent(x,y)
# Out:
# 0 0 89.0 0
# 0.62 0.18 52.25039999999999 1
# 1.0928 0.3192 30.831949440000002 2
# 1.453232 0.42724799999999996 18.347751350784 3
# 1.7278860800000002 0.5115091199999999 11.070010749324897 4
# 1.9370605952000002 0.5776057727999999 6.826353152519786 5
# 2.096250917888 0.6298300216319999 4.350826141683065 6
# 2.2172859146547204 0.6714583661260799 2.9056952040975976 7
# 2.309195511463117 0.7049920439242751 2.0610450731046615 8
# 2.3788729763057748 0.7323404723580026 1.5663423003130599 9
# 2.431580493177024 0.7549612843324961 1.2755882811903883 10
# 2.471335107618129 0.7739672290552247 1.1037021437989751 11
# 2.501203350198827 0.7902077780170325 1.0011028556851886 12
# 2.523526146474063 0.8043314214447622 0.9388969341253388 13
# 2.5400905089630834 0.8168332242274232 0.9002465769594267 14
# 2.55226060353756 0.8280911292050898 0.8753394365713272 15
# 2.561077803006991 0.8383936704087344 0.8584572531892551 16
# 2.567337066120929 0.8479611288201402 0.8462675994905574 17
# ...
